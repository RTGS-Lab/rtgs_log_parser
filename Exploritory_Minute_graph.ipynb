# %%
import os
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

# %%
test0 = pd.read_csv("Merged_Data_8_9_2022/concatCSV_0.csv")
test1 = pd.read_csv("Merged_Data_8_9_2022/concatCSV_1.csv")
test2 = pd.read_csv("Merged_Data_8_9_2022/concatCSV_2.csv")
test3 = pd.read_csv("Merged_Data_8_9_2022/concatCSV_3.csv")
test4 = pd.read_csv("Merged_Data_8_9_2022/concatCSV_4.csv")
# Out:
# D:\Users\Owner\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (4,5,13,15,17,22,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# D:\Users\Owner\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (8,9,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# D:\Users\Owner\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (4,5,19,20,21,22,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
test0
# Out:
#                   DEVICE_NAME                   NODE_ID OG_FILENAME  \
# 0      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 1      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 2      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 3      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 4      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# ...                       ...                       ...         ...
# 61809  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
# 61810  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
# 61811  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
# 61812  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
# 61813  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
#
#             Col_0     Col_1     Col_2     Col_3      Col_4      Col_5  \
# 0      1605543688  0.019531 -0.781441  3.437500  50.793652  63.922119
# ...

# %%
datetime.fromtimestamp(1638248714)
# Out:
# datetime.datetime(2021, 11, 29, 23, 5, 14)

# %%
datetime.fromtimestamp(1605543688)
# Out:
# datetime.datetime(2020, 11, 16, 10, 21, 28)

# %%
test1
# Out:
#                     DEVICE_NAME                   NODE_ID OG_FILENAME  \
# 0       Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# 1       Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# 2       Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# 3       Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# 4       Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# ...                         ...                       ...         ...
# 235029  Winter_Turf_Type_A_-_24  e00fce68a0322349e64ec178  2032-02-01
# 235030  Winter_Turf_Type_A_-_24  e00fce68a0322349e64ec178  2032-02-01
# 235031  Winter_Turf_Type_A_-_24  e00fce68a0322349e64ec178  2032-02-01
# 235032  Winter_Turf_Type_A_-_24  e00fce68a0322349e64ec178  2032-02-01
# 235033  Winter_Turf_Type_A_-_24  e00fce68a0322349e64ec178  2032-02-01
#
#         Time.0.TIME SHTC3.0.HUMIDITY SHTC3.0.TEMPERATURE  TCS3400.0.LIGHT_RED  \
# ...

# %%
datetime.fromtimestamp(943920001)
# Out:
# datetime.datetime(1999, 11, 29, 18, 0, 1)

# %%
datetime.fromtimestamp(1642249855)
# Out:
# datetime.datetime(2022, 1, 15, 6, 30, 55)

# %%
dfs = [test0, test1, test2, test3, test4]

# %%
dfs
# Out:
# [                  DEVICE_NAME                   NODE_ID OG_FILENAME  \
#  0      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
#  1      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
#  2      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
#  3      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
#  4      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
#  ...                       ...                       ...         ...
#  61809  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
#  61810  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
#  61811  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
#  61812  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
#  61813  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
#
#              Col_0     Col_1     Col_2     Col_3      Col_4      Col_5  \
# ...

# %%
for df in dfs:
    df = df.sort_values(by = [df.columns[1], df.columns[3]])

# %%
test0
# Out:
#                   DEVICE_NAME                   NODE_ID OG_FILENAME  \
# 0      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 1      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 2      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 3      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 4      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# ...                       ...                       ...         ...
# 61809  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
# 61810  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
# 61811  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
# 61812  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
# 61813  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
#
#             Col_0     Col_1     Col_2     Col_3      Col_4      Col_5  \
# 0      1605543688  0.019531 -0.781441  3.437500  50.793652  63.922119
# ...

# %%
for df in dfs:
    Dates = []
    for date in df.iloc[:,3]:
        Dates.append(datetime.fromtimestamp(date))
    df.insert(3, "Date", Dates)

# %%
test0
# Out:
#                   DEVICE_NAME                   NODE_ID OG_FILENAME  \
# 0      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 1      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 2      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 3      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 4      Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# ...                       ...                       ...         ...
# 61809  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
# 61810  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
# 61811  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
# 61812  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
# 61813  Winter_Turf_Type_B_-_1  e00fce6838cebdf42fc24391  2021-11-29
#
#                      Date       Col_0     Col_1     Col_2     Col_3  \
# 0     2020-11-16 10:21:28  1605543688  0.019531 -0.781441  3.437500
# ...

# %%
sample = test0.head(300)

# %%
sample
# Out:
#                 DEVICE_NAME                   NODE_ID OG_FILENAME  \
# 0    Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 1    Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 2    Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 3    Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# 4    Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2000-00-01
# ..                      ...                       ...         ...
# 295  Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2020-11-23
# 296  Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2020-11-23
# 297  Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2020-11-23
# 298  Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2020-11-23
# 299  Winter_Turf_Type_B_-_6  e00fce685b02f35fe13a0a2d  2020-11-23
#
#                    Date       Col_0     Col_1     Col_2     Col_3      Col_4  \
# 0   2020-11-16 10:21:28  1605543688  0.019531 -0.781441  3.437500  50.793652
# ...

# %%
t1 = 0 
t2 = t1 + 1
diff = []
for date in sample["Date"]:
    if t2 >= 300:
        print("Done")
        pass
    else:
        diff.append(sample["Date"][t2] - sample["Date"][t1])
    t1 = t1 + 1
    t2 = t2 + 1
# Out:
# Done

# %%
sample.index
# Out:
# RangeIndex(start=0, stop=300, step=1)

# %%
len(diff )
# Out:
# 299

# %%
sample["Date"][0].minute
# Out:
# 21

# %%
count = []
minutes = []
n = 0
for i in diff:
    count.append(n)
    minutes.append(i.total_seconds()/60)
    n= n + 1
sample_min = pd.DataFrame({"Index":count, "Min":minutes})

# %%
sample_min
# Out:
#      Index        Min
# 0        0  15.766667
# 1        1  15.783333
# 2        2  15.783333
# 3        3  16.083333
# 4        4  15.766667
# ..     ...        ...
# 294    294  15.783333
# 295    295  20.000000
# 296    296  16.083333
# 297    297  15.766667
# 298    298  15.783333
#
# [299 rows x 2 columns]

# %%
ax= sb.scatterplot(x = "Index", y = "Min", data = sample_min)

# %%
sample_min["Min"].min()
# Out:
# 15.733333333333333

# %%
sample_min["Min"].max()
# Out:
# 4529.0
