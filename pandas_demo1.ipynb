# %%
import os
import pandas as pd

# %%
path_to_final_merged = r"C:\Users\michaelfelzan\Documents\rtgs_parse\final_merged"

# %%
for file in os.listdir(path_to_final_merged):
    print(file)
# Out:
# concatCSV_0.csv
# concatCSV_1.csv
# concatCSV_2.csv
# concatCSV_3.csv
# concatCSV_4.csv

# %%
path_to_concats = []

for file in os.listdir(path_to_final_merged):
    concatCSVpath = os.path.join(path_to_final_merged,file)
    print(concatCSVpath)
    path_to_concats.append(concatCSVpath)
# Out:
# C:\Users\michaelfelzan\Documents\rtgs_parse\final_merged\concatCSV_0.csv
# C:\Users\michaelfelzan\Documents\rtgs_parse\final_merged\concatCSV_1.csv
# C:\Users\michaelfelzan\Documents\rtgs_parse\final_merged\concatCSV_2.csv
# C:\Users\michaelfelzan\Documents\rtgs_parse\final_merged\concatCSV_3.csv
# C:\Users\michaelfelzan\Documents\rtgs_parse\final_merged\concatCSV_4.csv

# %%
concat_1 = path_to_concats[1]
print(concat_1)
# Out:
# C:\Users\michaelfelzan\Documents\rtgs_parse\final_merged\concatCSV_1.csv

# %%
df = pd.read_csv(concat_1)

for i, col in enumerate(df.columns):
    print(i, col)
# Out:
# 0 DEVICE_NAME
# 1 NODE_ID
# 2 OG_FILENAME
# 3 Time.0.TIME
# 4 SHTC3.0.HUMIDITY
# 5 SHTC3.0.TEMPERATURE
# 6 TCS3400.0.LIGHT_RED
# 7 TCS3400.0.LIGHT_GREEN
# 8 TCS3400.0.LIGHT_BLUE
# 9 PAC1720.0.VOLTAGE
# 10 PAC1720.0.CURRENT
# 11 PAC1720.0.VOLTAGE_2
# 12 PAC1720.0.CURRENT_2
# 13 DS18.0
# 14 SoilMoisture.0
# 15 DS18.1
# 16 SoilMoisture.1
# 17 DS18.2
# 18 SoilMoisture.2
# 19 ApogeeO2.0.TEMPERATURE
# 20 ApogeeO2.0.REF
# 21 ApogeeO2.0.OXYGEN
# 22 Hedorah-NDIR.0.CO2
# 23 Hedorah-NDIR.0.HUMIDITY
# 24 Hedorah-NDIR.0.TEMPERATURE

# %%
df.head()
# Out:
#                DEVICE_NAME                   NODE_ID OG_FILENAME  Time.0.TIME  \
# 0  Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00    943920001
# 1  Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00    943920037
# 2  Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00   1639242251
# 3  Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00   1639243305
# 4  Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00   1639244238
#
#   SHTC3.0.HUMIDITY SHTC3.0.TEMPERATURE  TCS3400.0.LIGHT_RED  \
# 0        10.978699            0.573807             0.013062
# 1        11.053467             0.60585             0.013672
# 2        10.928345             0.51239             0.015137
# 3        11.061096            0.573807             0.010620
# 4          11.0672            0.386887             0.002197
#
#    TCS3400.0.LIGHT_GREEN  TCS3400.0.LIGHT_BLUE  PAC1720.0.VOLTAGE  ...  \
# ...

# %%
A12_data = df[df["NODE_ID"]=="e00fce68b6dc19eefd628b4e"]
A12_data
# Out:
#                    DEVICE_NAME                   NODE_ID OG_FILENAME  \
# 0      Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# 1      Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# 2      Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# 3      Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# 4      Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# ...                        ...                       ...         ...
# 10606  Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2021-12-12
# 10607  Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2021-12-12
# 10608  Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2021-12-12
# 10609  Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2021-12-12
# 10610  Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2021-12-12
#
#        Time.0.TIME SHTC3.0.HUMIDITY SHTC3.0.TEMPERATURE  TCS3400.0.LIGHT_RED  \
# ...
