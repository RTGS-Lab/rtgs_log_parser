# %%
import os
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df0 = pd.read_csv("Merged_Data_8_9_2022/concatCSV_0.csv") ## Merged Dataframes (Change to path of dataframe)
df1 = pd.read_csv("Merged_Data_8_9_2022/concatCSV_1.csv")
df2 = pd.read_csv("Merged_Data_8_9_2022/concatCSV_2.csv")
df3 = pd.read_csv("Merged_Data_8_9_2022/concatCSV_3.csv")
df4 = pd.read_csv("Merged_Data_8_9_2022/concatCSV_4.csv")
# Out:
# D:\Users\Owner\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (4,5,13,15,17,22,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# D:\Users\Owner\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (8,9,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# D:\Users\Owner\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (4,5,19,20,21,22,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def Numerical_Convert(df):
    n = 0
    Node_List= df["NODE_ID"]
#     for Nodes in Node_List:
#         Node = df[(df["NODE_ID"] == Nodes)]
    for col in df.columns:
        try:
            float(df[col].iloc[0])
            df[col + "_Numeric"] = pd.to_numeric(df[col], errors = "coerce") 
        except:
            print("Column " + str(col) + " is not Numerical")
            continue

# %%
Numerical_Convert(df1)
# Out:
# Column DEVICE_NAME is not Numerical
# Column NODE_ID is not Numerical
# Column OG_FILENAME is not Numerical

# %%
df1
# Out:
#                     DEVICE_NAME                   NODE_ID OG_FILENAME  \
# 0       Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# 1       Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# 2       Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# 3       Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# 4       Winter_Turf_Type_A_-_12  e00fce68b6dc19eefd628b4e  2000-00-00
# ...                         ...                       ...         ...
# 235029  Winter_Turf_Type_A_-_24  e00fce68a0322349e64ec178  2032-02-01
# 235030  Winter_Turf_Type_A_-_24  e00fce68a0322349e64ec178  2032-02-01
# 235031  Winter_Turf_Type_A_-_24  e00fce68a0322349e64ec178  2032-02-01
# 235032  Winter_Turf_Type_A_-_24  e00fce68a0322349e64ec178  2032-02-01
# 235033  Winter_Turf_Type_A_-_24  e00fce68a0322349e64ec178  2032-02-01
#
#         Time.0.TIME SHTC3.0.HUMIDITY SHTC3.0.TEMPERATURE  TCS3400.0.LIGHT_RED  \
# 0         943920001          10.9787            0.573807             0.013062
# 1         943920037          11.0535             0.60585             0.013672
# 2        1639242251          10.9283             0.51239             0.015137
# 3        1639243305          11.0611            0.573807             0.010620
# 4        1639244238          11.0672            0.386887             0.002197
# ...             ...              ...                 ...                  ...
# 235029   1642249855        20.623779            3.353577             0.055542
# 235030   1642277168        20.281982            3.238754             0.060822
# 235031   1642282884        20.214844            3.353577             0.060791
# 235032   1642288599        20.167542            3.292160             0.060211
# 235033   1642294314        20.115662            3.353577             0.059326
#
#         TCS3400.0.LIGHT_GREEN  TCS3400.0.LIGHT_BLUE  PAC1720.0.VOLTAGE  ...  \
# 0                    0.014893              0.014526           3.613281  ...
# 1                    0.014526              0.013428           6.015625  ...
# 2                    0.015869              0.014526           6.171875  ...
# 3                    0.011597              0.010864           6.054687  ...
# 4                    0.003296              0.003906           5.800781  ...
# ...                       ...                   ...                ...  ...
# 235029               0.054230              0.057678           5.644531  ...
# 235030               0.059052              0.062469           5.703125  ...
# 235031               0.059082              0.062469           5.683594  ...
# 235032               0.058624              0.061951           5.703125  ...
# 235033               0.057800              0.061127           5.703125  ...
#
#         DS18.1_Numeric  SoilMoisture.1_Numeric  DS18.2_Numeric  \
# 0               0.0625                1.601660           0.500
# 1               0.0625                1.611328           0.500
# 2               0.0625                1.605688           0.500
# 3               0.0625                1.599243           0.500
# 4               0.0625                1.612134           0.500
# ...                ...                     ...             ...
# 235029          0.5625                0.058008           0.625
# 235030          0.5000                0.060425           0.625
# 235031          0.5625                0.056396           0.625
# 235032          0.5000                0.058008           0.625
# 235033          0.5000                0.057202           0.625
#
#        SoilMoisture.2_Numeric  ApogeeO2.0.TEMPERATURE_Numeric  \
# 0                    1.180298                       1083.0000
# 1                    1.180298                       1083.7500
# 2                    1.187549                       1083.9375
# 3                    1.189160                       1083.1875
# 4                    1.187549                       1083.0000
# ...                       ...                             ...
# 235029               0.280371                       2825.2500
# 235030               0.270703                       2824.5000
# 235031               0.266675                       2824.8750
# 235032               0.268286                       2825.0625
# 235033               0.266675                       2824.8750
#
#        ApogeeO2.0.REF_Numeric  ApogeeO2.0.OXYGEN_Numeric  \
# 0                   2497.6875                    10.5000
# 1                   2497.6875                    10.5000
# 2                   2497.3125                    10.5000
# 3                   2497.6875                    10.5000
# 4                   2497.5000                    10.6875
# ...                       ...                        ...
# 235029              2499.3750                    11.8125
# 235030              2499.5625                    11.8125
# 235031              2499.1875                    12.0000
# 235032              2499.5625                    11.8125
# 235033              2499.3750                    11.8125
#
#        Hedorah-NDIR.0.CO2_Numeric  Hedorah-NDIR.0.HUMIDITY_Numeric  \
# 0                          4118.0                        95.359802
# 1                          4122.0                        94.972229
# 2                          4111.0                        94.757080
# 3                          4171.0                        95.359802
# 4                          4124.0                        95.414734
# ...                           ...                              ...
# 235029                     7073.0                        91.708374
# 235030                     7144.0                        93.743896
# 235031                     7033.0                        92.797852
# 235032                     7106.0                        92.182922
# 235033                     7084.0                        91.708374
#
#         Hedorah-NDIR.0.TEMPERATURE_Numeric
# 0                                 0.195316
# 1                                 0.307468
# 2                                 0.320820
# 3                                 0.195316
# 4                                 0.208668
# ...                                    ...
# 235029                            1.183338
# 235030                            0.748074
# 235031                            0.943008
# 235032                            1.111237
# 235033                            1.183338
#
# [235034 rows x 47 columns]

# %%
df0["Col_8_Numeric"].isnull().values.any()
# Out:
# False

# %%
col_num = list(range(28))

# %%
for col in col_num:
    result = df0["Col_" + str(col) + "_Numeric"].isnull().values.any()
    print(result)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
