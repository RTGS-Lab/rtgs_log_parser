# %%
import os
from datetime import datetime, timezone
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Merged Dataframes That have Headers (Change to path of dataframe)
df0 = pd.read_csv("Version/1_MergedCSV_0.csv")
df1 = pd.read_csv("Version/1_MergedCSV_1.csv")
df2 = pd.read_csv("Version/1_MergedCSV_2.csv")
df3 = pd.read_csv("Version/1_MergedCSV_3.csv")
df4 = pd.read_csv("Version/1_MergedCSV_4.csv")

# %%
dfs = [df0, df1, df2, df3, df4]

# %%
Folder_col = []
Node_col = []
Startdate = []
Enddate = []
Expected_col = []
Actual_col = []
Rate_col = []

for df in dfs:
    print("\n")
    Folder = str(df["MERGE_FOLD_INDX"].iloc[0])
    Time_col = df.columns[6]                 ##Timestamp column for each dataframe
    node_list = df["NODE_ID"].unique()
    for Nodes in node_list:
        Node = df[(df["NODE_ID"] == Nodes)]
        
        Time1 = Node[(Node["ISO8601_DATE"] >= datetime(2019, 3, 16, tzinfo = timezone.utc).isoformat())&(Node["ISO8601_DATE"] <= datetime(2020, 3, 15, tzinfo = timezone.utc).isoformat())]
        Start = Time1["ISO8601_DATE"].min()
        End = Time1["ISO8601_DATE"].max()
        result = Time1[Time_col].max()-Time1[Time_col].min()
        if not np.isnan(result):
            expected = int(result/(60*15))                                ## Seconds to 15 minute intervals
            actual = len(Time1)                                           ## Length of time dataframe
            rate = round((actual/expected * 100), 2)                      ## Percent  Rate
            Folder_col.append(Folder)
            Node_col.append(Nodes)
            Startdate.append(Start)
            Enddate.append(End)
            Expected_col.append(expected)
            Actual_col.append(actual)
            Rate_col.append(rate)
            print("Done with ", Folder, Nodes, "2019-2020 dates..." )
        else:
            print(Folder, Nodes, "Has no dates in 2019-2020...")
            
            
        
        Time2 = Node[(Node["ISO8601_DATE"] >= datetime(2020, 3, 16, tzinfo = timezone.utc).isoformat())&(Node["ISO8601_DATE"] <= datetime(2021, 3, 15, tzinfo = timezone.utc).isoformat())]
        Start = Time2["ISO8601_DATE"].min()
        End = Time2["ISO8601_DATE"].max()
        result = Time2[Time_col].max() - Time2[Time_col].min() 
        if not np.isnan(result):
            expected = int(result/(60*15))                                ## Seconds to 15 minute intervals
            actual = len(Time2)                                           ## Length of time dataframe
            rate = round((actual/expected * 100), 2)                      ## Percent  Rate
            Folder_col.append(Folder)
            Node_col.append(Nodes)
            Startdate.append(Start)
            Enddate.append(End)
            Expected_col.append(expected)
            Actual_col.append(actual)
            Rate_col.append(rate)
            print("Done with ", Folder, Nodes, "2020-2021 dates..." )
        else:
            print(Folder, Nodes, "Has no dates in 2020-2021...")
            
    
        Time3 = Node[(Node["ISO8601_DATE"] >= datetime(2021, 3, 16, tzinfo = timezone.utc).isoformat())&(Node["ISO8601_DATE"] <= datetime(2022, 3, 15, tzinfo = timezone.utc).isoformat())]
        Start = Time3["ISO8601_DATE"].min()
        End = Time3["ISO8601_DATE"].max()
        result = Time3[Time_col].max()-Time3[Time_col].min()
        if not np.isnan(result):
            expected = int(result/(60*15))                                ## Seconds to 15 minute intervals
            actual = len(Time3)                                           ## Length of time dataframe
            rate = round((actual/expected * 100), 2)                      ## Percent  Rate
            Folder_col.append(Folder)
            Node_col.append(Nodes)
            Startdate.append(Start)
            Enddate.append(End)
            Expected_col.append(expected)
            Actual_col.append(actual)
            Rate_col.append(rate)
            print("Done with ", Folder, Nodes, "2021-2022 dates..." )
        else:
            print(Folder, Nodes, " Has no dates in 2021-2022...")
print("\n Creating Dataframe...")
Ping_df= pd.DataFrame({"Folder_Index":Folder_col, 
                                 "Node":Node_col, 
                                 "Start_Date":Startdate, 
                                 "End_Date":Enddate, 
                                "Expected_Pings":Expected_col, 
                                 "Observed_Pings":Actual_col,
                                "Percent_Rate":Rate_col})
Ping_df.to_csv("Node_Times.csv", index = False)
print("\n Node Ping Dataframe Complete!!!")
# Out:
# 0 e00fce686ef282d1d03ac481 Has no dates in 2019-2020...
# Done with  0 e00fce686ef282d1d03ac481 2020-2021 dates...
# Done with  0 e00fce686ef282d1d03ac481 2021-2022 dates...
# 0 e00fce6893c0acfa1ee9ed4a Has no dates in 2019-2020...
# Done with  0 e00fce6893c0acfa1ee9ed4a 2020-2021 dates...
# Done with  0 e00fce6893c0acfa1ee9ed4a 2021-2022 dates...
# 0 e00fce68b13222b0287269a6 Has no dates in 2019-2020...
# Done with  0 e00fce68b13222b0287269a6 2020-2021 dates...
# Done with  0 e00fce68b13222b0287269a6 2021-2022 dates...
# 0 e00fce685b02f35fe13a0a2d Has no dates in 2019-2020...
# Done with  0 e00fce685b02f35fe13a0a2d 2020-2021 dates...
# Done with  0 e00fce685b02f35fe13a0a2d 2021-2022 dates...
# 0 e00fce6856706b033b691f8b Has no dates in 2019-2020...
# Done with  0 e00fce6856706b033b691f8b 2020-2021 dates...
# Done with  0 e00fce6856706b033b691f8b 2021-2022 dates...
# 0 e00fce682c26b88b84ab26f2 Has no dates in 2019-2020...
# Done with  0 e00fce682c26b88b84ab26f2 2020-2021 dates...
# Done with  0 e00fce682c26b88b84ab26f2 2021-2022 dates...
# 0 e00fce6891afbb6bddd89915 Has no dates in 2019-2020...
# Done with  0 e00fce6891afbb6bddd89915 2020-2021 dates...
# Done with  0 e00fce6891afbb6bddd89915 2021-2022 dates...
# 0 e00fce68978c5c1897d17ac7 Has no dates in 2019-2020...
# Done with  0 e00fce68978c5c1897d17ac7 2020-2021 dates...
# Done with  0 e00fce68978c5c1897d17ac7 2021-2022 dates...
# 0 e00fce68fb8a948ec07bb826 Has no dates in 2019-2020...
# Done with  0 e00fce68fb8a948ec07bb826 2020-2021 dates...
# Done with  0 e00fce68fb8a948ec07bb826 2021-2022 dates...
# 0 e00fce6838cebdf42fc24391 Has no dates in 2019-2020...
# Done with  0 e00fce6838cebdf42fc24391 2020-2021 dates...
# Done with  0 e00fce6838cebdf42fc24391 2021-2022 dates...
#
#
# 1 e00fce6893c0acfa1ee9ed4a Has no dates in 2019-2020...
# 1 e00fce6893c0acfa1ee9ed4a Has no dates in 2020-2021...
# Done with  1 e00fce6893c0acfa1ee9ed4a 2021-2022 dates...
# 1 e00fce6838cebdf42fc24391 Has no dates in 2019-2020...
# 1 e00fce6838cebdf42fc24391 Has no dates in 2020-2021...
# Done with  1 e00fce6838cebdf42fc24391 2021-2022 dates...
# 1 e00fce6891afbb6bddd89915 Has no dates in 2019-2020...
# 1 e00fce6891afbb6bddd89915 Has no dates in 2020-2021...
# Done with  1 e00fce6891afbb6bddd89915 2021-2022 dates...
# 1 e00fce6856706b033b691f8b Has no dates in 2019-2020...
# 3 e00fce681171349b5773ef72 Has no dates in 2020-2021...
# Done with  3 e00fce681171349b5773ef72 2021-2022 dates...
# 3 e00fce68a0322349e64ec178 Has no dates in 2019-2020...
# 3 e00fce68a0322349e64ec178 Has no dates in 2020-2021...
# Done with  3 e00fce68a0322349e64ec178 2021-2022 dates...
#
#
# 4 e00fce687038a71d446ef776 Has no dates in 2019-2020...
# 4 e00fce687038a71d446ef776 Has no dates in 2020-2021...
# Done with  4 e00fce687038a71d446ef776 2021-2022 dates...
# 4 e00fce688c30491f7bf87fb2 Has no dates in 2019-2020...
# 4 e00fce688c30491f7bf87fb2 Has no dates in 2020-2021...
# Done with  4 e00fce688c30491f7bf87fb2 2021-2022 dates...
# 4 e00fce682699a15d165801b1 Has no dates in 2019-2020...
# 4 e00fce682699a15d165801b1 Has no dates in 2020-2021...
# Done with  4 e00fce682699a15d165801b1 2021-2022 dates...
# 4 e00fce681171349b5773ef72 Has no dates in 2019-2020...
# 4 e00fce681171349b5773ef72 Has no dates in 2020-2021...
# Done with  4 e00fce681171349b5773ef72 2021-2022 dates...
# 4 e00fce68a0322349e64ec178 Has no dates in 2019-2020...
# 4 e00fce68a0322349e64ec178 Has no dates in 2020-2021...
# Done with  4 e00fce68a0322349e64ec178 2021-2022 dates...
# 4 e00fce68744c7380377ec9e4 Has no dates in 2019-2020...
# 4 e00fce68744c7380377ec9e4 Has no dates in 2020-2021...
# Done with  4 e00fce68744c7380377ec9e4 2021-2022 dates...
#
#  Creating Dataframe...
#
#  Node Ping Dataframe Complete!!!

# %%
Ping_df
# Out:
#    Folder_Index                      Node            Start_Date  \
# 0             0  e00fce686ef282d1d03ac481  2020-11-16T17:28:52Z
# 1             0  e00fce686ef282d1d03ac481  2021-03-16T00:12:53Z
# 2             0  e00fce6893c0acfa1ee9ed4a  2020-11-16T20:02:34Z
# 3             0  e00fce6893c0acfa1ee9ed4a  2021-03-16T00:05:34Z
# 4             0  e00fce68b13222b0287269a6  2020-11-16T17:32:56Z
# ..          ...                       ...                   ...
# 86            4  e00fce688c30491f7bf87fb2  2021-12-13T22:35:27Z
# 87            4  e00fce682699a15d165801b1  2021-12-13T22:23:42Z
# 88            4  e00fce681171349b5773ef72  2021-12-14T19:29:32Z
# 89            4  e00fce68a0322349e64ec178  2022-01-12T20:11:15Z
# 90            4  e00fce68744c7380377ec9e4  2022-02-07T19:42:58Z
#
#                 End_Date  Expected_Pings  Observed_Pings  Percent_Rate
# 0   2021-03-14T23:55:23Z           11353            9673         85.20
# 1   2021-04-06T23:05:35Z            2107            1927         91.46
# 2   2021-03-14T23:59:24Z           11343           10253         90.39
# 3   2021-11-02T19:56:36Z           22255            2768         12.44
# 4   2021-03-12T11:41:48Z           11112            8962         80.65
# ..                   ...             ...             ...           ...
# 86  2021-12-17T05:38:41Z             316             293         92.72
# 87  2022-03-14T23:47:58Z            8741            8081         92.45
# 88  2021-12-14T19:49:31Z               1               3        300.00
# 89  2022-03-14T23:54:47Z            5870            5413         92.21
# 90  2022-02-27T05:27:29Z            1862            1717         92.21
#
# [91 rows x 7 columns]

# %%
sns.histplot(data = Ping_df, x = "Percent_Rate")
# Out:
# <AxesSubplot:xlabel='Percent_Rate', ylabel='Count'>
