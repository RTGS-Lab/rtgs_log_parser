# %% [markdown]
# # Numerical Conversion and Range Checking
#
# This notebook converts numerical columns valid numerical data and then checks the range for each column. First, csvs with known headers will be uploaded. Then numerical conversion will be done by check the first row of each column. Finally, ranges with be check to see if the column values are reasonalbe.
#
# Luke Rosen
#
# 8/22/2022
#
#
# 8/24/2022
#
# Changed column names and added versioning. Checks the last column as will for numerical converion.

# %%
import os
from datetime import datetime
import pandas as pd
import numpy as np

# %%
## Merged Dataframes That have Headers (Change to path of dataframe)




df1 = pd.read_csv("Version/3_MergedCSV_1.csv")
df3 = pd.read_csv("Version/3_MergedCSV_3.csv")
df4 = pd.read_csv("Version/3_MergedCSV_4.csv")

# %%
dfs = [ df1,  df3, df4]

# %% [markdown]
# ## Range Checking
#
# This next cell uses column names and acceptible ranges (Discussed with GEMS) to check if all values in the columnh are within that range. For each column in the dataframe, a condition is established as None. Then the conditon changes dependeing if the column range values are accepable (True), or unacceptible (False).
#
# The inclusive ranges are:
#
# "ApogeeO2" (including "ApogeeO2.*.TEMPATURE") 3000-3000
#
# "TEMPERATURE" -40-85  degrees celcius
#
# "DS18" Same as temperature.
#
# "HUMIDITY"  0-100 Percent
#
# "LIGHT" Anything greater than 0 (0-2^16)
#
# "TIME" Between January 1st 2019 and May 31st 2022 (Need to change)
#
# "SoilMoisture" 0-3
#
# "CURRENT" -1000-1000
#
# "VOLTAGE" 0-12
#
# "CO2" 400-10000
#
# Notes:
#
# "ApogeeO2" conditon must be done before "TEMPERATURE" otherwise  "ApogeeO2.*.TEMPATURE" will have incorrect ranges.
#
# NA values must be dropped or the condition will result in False even if all other values are within range.

# %%
def range_check(df):
    for col in df.columns[7:]:
        locals()[col + "_Rate"] = []
    
    for col in df.columns[7:]:
        condition = None
        if "ApogeeO2" in col:
            condition = df[col].between(-3000, 3000).all()
            if condition == True:
                rate = 100
                locals()[col + "_Rate"].append(rate)
            else:
                n = 0
                condition = df[col].between(-3000, 3000)
                for i in condition:
                    if i == True:
                        n= n + 1
                    else:
                        continue
                rate = round((n/len(df) * 100), 2)
                locals()[col + "_Rate"].append(rate)
        elif "TEMPERATURE"  in col:
            condition = df[col].between(-40, 85).all()
            if condition == True:
                rate = 100
                locals()[col + "_Rate"].append(rate)
            else:
                n = 0
                condition = df[col].between(-40, 85)
                for i in condition:
                    if i == True:
                        n = n + 1
                    else:
                        continue
                rate = round((n/len(df) * 100), 2) 
                locals()[col + "_Rate"].append(rate)
            
        elif "DS18"  in col:
            condition = df[col].between(-40, 85).all()
            if condition == True:
                rate = 100
                locals()[col + "_Rate"].append(rate)
            else:
                n = 0
                condition = df[col].between(-40, 85)
                for i in condition:
                    if i  == True:
                        n = n + 1
                    else:
                        continue
                rate = round((n/len(df) * 100), 2) 
                locals()[col + "_Rate"].append(rate)
        elif "HUMIDITY" in col:
            condition = df[col].between(0, 100).all()
            if condition == True:
                rate = 100
                locals()[col + "_Rate"].append(rate)
            else:
                n = 0
                condition = df[col].between(0, 100)
                for i in condition:
                    if i == True:
                        n = n + 1
                    else:
                        continue
                rate = round((n/len(df) * 100), 2) 
                locals()[col + "_Rate"].append(rate)
            
        elif "LIGHT" in col:
            condition = df[col].between(0, 2**16).all()
            if condition == True:
                rate = 100
                locals()[col + "_Rate"].append(rate)
            else:
                n = 0
                condition = df[col].between(0, 2**16)
                for i in condition:
                    if i == True:
                        n = n + 1
                    else:
                        continue
                rate = round((n/len(df) * 100), 2) 
                locals()[col + "_Rate"].append(rate)
  
        elif "TIME" in col:
            condition = df[col].between(datetime.timestamp(datetime(2019, 1, 1)), datetime.timestamp(datetime(2022, 4, 30))).all() ##Change Later
            if condition == True:
                rate = 100
                locals()[col + "_Rate"].append(rate)
            else:
                n = 0
                condition = df[col].between(datetime.timestamp(datetime(2019, 1, 1)), datetime.timestamp(datetime(2022, 4, 30)))
                for i in condition:
                    if i == True:
                        n = n + 1
                    else:
                        continue
                rate = round((n/len(df) * 100), 2) 
                locals()[col + "_Rate"].append(rate)

        elif "SoilMoisture" in col:
            condition = df[col].between(0, 3).all()
            if condition == True:
                rate = 100
                locals()[col + "_Rate"].append(rate)
            else:
                n = 0
                condition = df[col].between(0, 3)
                for i in condition:
                    if i == True:
                        n = n + 1
                    else:
                        continue
                rate = round((n/len(df) * 100), 2) 
                locals()[col + "_Rate"].append(rate)

        elif "CURRENT" in col:
            condition = df[col].between(-1000, 1000).all()
            if condition == True:
                rate = 100
                locals()[col + "_Rate"].append(rate)
            else:
                n = 0
                condition = df[col].between(-1000, 1000)
                for i in condition:
                    if i == True:
                        n = n + 1
                    else:
                        continue
                rate = round((n/len(df) * 100), 2) 
                locals()[col + "_Rate"].append(rate)
            
        elif "VOLTAGE" in col:
            condition = df[col].between(0, 12).all()
            if condition == True:
                rate = 100
                locals()[col + "_Rate"].append(rate)
            else:
                n = 0
                condition = df[col].between(0, 12)
                for i in condition:
                    if i == True:
                        n = n + 1
                    else:
                        continue
                rate = round((n/len(df) * 100), 2) 
                locals()[col + "_Rate"].append(rate)
            
        elif "CO2" in col:
            condition = df[col].between(400, 10000).all()
            if condition == True:
                rate = 100
                locals()[col + "_Rate"].append(rate)
            else:
                n = 0
                condition = df[col].between(0, 2**16)
                for i in condition:
                    if i == True:
                        n = n + 1
                    else:
                        continue
                rate = round((n/len(df) * 100), 2) 
                locals()[col + "_Rate"].append(rate)
        

        else:
            print("Skipping Column " + str(col) + "...")
        print(str(col) + "_Rate:" +  str(locals()[col + "_Rate"]) + "\n") 
        

        
        
    print("\n" + str(len(df)) +  " Range Check Complete!!!")

# %%
range_check(df1)
# Out:
# TIMESTAMP_Rate:[82.84]
#
# SHTC3.0.HUMIDITY_Rate:[99.96]
#
# SHTC3.0.TEMPERATURE_Rate:[99.96]
#
# TCS3400.0.LIGHT_RED_Rate:[99.95]
#
# TCS3400.0.LIGHT_GREEN_Rate:[99.97]
#
# TCS3400.0.LIGHT_BLUE_Rate:[99.99]
#
# PAC1720.0.VOLTAGE_Rate:[99.98]
#
# PAC1720.0.CURRENT_Rate:[100.0]
#
# PAC1720.0.VOLTAGE_2_Rate:[99.99]
#
# PAC1720.0.CURRENT_2_Rate:[99.99]
#
# ApogeeO2.0.TEMPERATURE_Rate:[99.94]
#
# ApogeeO2.0.REF_Rate:[99.94]
#
# ApogeeO2.0.OXYGEN_Rate:[100.0]
#
# ApogeeO2.1.TEMPERATURE_Rate:[99.98]
#
# ApogeeO2.1.REF_Rate:[99.98]
#
# ApogeeO2.1.OXYGEN_Rate:[100]
#
# Hedorah-NDIR.0.CO2_Rate:[97.92]
#
# Hedorah-NDIR.0.HUMIDITY_Rate:[97.92]
#
# Hedorah-NDIR.0.TEMPERATURE_Rate:[97.92]
#
# Hedorah-NDIR.1.CO2_Rate:[99.65]
#
# Hedorah-NDIR.1.HUMIDITY_Rate:[99.65]
#
# Hedorah-NDIR.1.TEMPERATURE_Rate:[99.65]
#
#
# 99506 Range Check Complete!!!

# %%
range_check(df3)

# %%
range_check(df4)

# %%
range_check(df0)

# %%
range_check(df1)

# %%
range_check(df2)

# %%
range_check(df3)

# %%
range_check(df4)

# %% [markdown]
# This notebook is complete.
